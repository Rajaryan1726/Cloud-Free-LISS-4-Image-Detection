# %% [markdown]
# # Cloud-Free Image Reconstruction using Deep Learning
#
# ## Notebook 01: Dataset Exploration
#
# ### Dataset
# SEN12MS-CR
#
# ### Goal
#
# This notebook explores the dataset structure before preprocessing.
#
# Tasks:
#
# - Verify dataset location
# - Explore folder hierarchy
# - Count ROI folders
# - Count GeoTIFF images
# - Verify dataset consistency
# - Generate dataset summary
#
# > This notebook does not modify the dataset.

# %%
# ==========================================================
# Cloud-Free Image Reconstruction using Deep Learning
# Notebook 01 : Dataset Exploration
# ==========================================================

print("=" * 60)
print("Cloud-Free Image Reconstruction")
print("Notebook 01 : Dataset Exploration")
print("=" * 60)
# Out:
# ...
# Cloud-Free Image Reconstruction
# Notebook 01 : Dataset Exploration
# ...

# %%
from pathlib import Path

import os

# %%
PROJECT_ROOT = Path.cwd().parent

print(PROJECT_ROOT)
# Out:
# c:\Cloud-Free-Reconstruction

# %%
DATA_ROOT = PROJECT_ROOT / "data" / "raw"

print(DATA_ROOT)
# Out:
# c:\Cloud-Free-Reconstruction\data\raw

# %%
print(DATA_ROOT.exists())
# Out:
# True
